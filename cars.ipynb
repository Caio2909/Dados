# %% [markdown]
# <a href="https://colab.research.google.com/github/Caio2909/Dados/blob/main/cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

cars1 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv')
cars2 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv')

# %%
owners= np.random.randint(15000,73001,398,dtype="l")
owners
# Out:
# array([17976, 27414, 42326, 51057, 33357, 46576, 23018, 30673, 63723,
#        41832, 43299, 68105, 65619, 25636, 24794, 28566, 19884, 67929,
#        21464, 56323, 38897, 27836, 41813, 26399, 40460, 26727, 45989,
#        70200, 15947, 43722, 42437, 70839, 62728, 56568, 39432, 18826,
#        28449, 58241, 24770, 43059, 40293, 18211, 22377, 58780, 61412,
#        48715, 29922, 22480, 32215, 21328, 57603, 27987, 17245, 61642,
#        18317, 48520, 28260, 47124, 70709, 46351, 62566, 48160, 25926,
#        15870, 54923, 51426, 37659, 67788, 51344, 46687, 69053, 21597,
#        36517, 45671, 24892, 24206, 62295, 15455, 17102, 40936, 61488,
#        22947, 22877, 53343, 61377, 72560, 59734, 38823, 67283, 48900,
#        46172, 35033, 16845, 29444, 34072, 49734, 70137, 41342, 38653,
#        44270, 58395, 54603, 43480, 30856, 45467, 17590, 29485, 70258,
#        59933, 34546, 22427, 37308, 34817, 68509, 44721, 24913, 72851,
# ...

# %%
cars1 = cars1.loc[:,:'car']
cars1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
#      origin                        car
# ...

# %%
cars = pd.merge(cars1, cars2,how="outer")
cars['owners'] = owners
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 393  27.0          4           140         86    2790          15.6     82
# 394  44.0          4            97         52    2130          24.6     82
# 395  32.0          4           135         84    2295          11.6     82
# 396  28.0          4           120         79    2625          18.6     82
# 397  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...
